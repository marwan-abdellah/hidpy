# %% [markdown]
# Verify the imports
# NOTE: Please do NOT edit this panel!

# %%
print('* Verifying the packages')
# System packages 
import os
import pathlib 
import sys 
import warnings
warnings.filterwarnings('ignore') # Ignore all the warnings 

# Path hidpy
sys.path.append('%s/../' % os.getcwd())

# Internal packages 
from core import file_utils
from core import optical_flow
from core import video_processing
from core import plotting
from core import msd
from core import inference

print('\t* All required packages were successfully imported!')
# Out:
# * Verifying the packages
# 	* All required packages were successfully imported!

# %%
############ INPUTS PANEL, YOU CAN EDIT THIS PANEL ############ 
# Input video sequence (single sequence)   
video_sequence = '%s/../data/microscopes/h2b/u2os-h2bgfp-serum-3.avi' % os.getcwd()
video_sequence = '%s/../data/microscopes/dna/3.avi' % os.getcwd()
#video_sequence = 'c:/Users/valad/Documents/GitHub/hidpy/notebooks/../data/microscopes/dna/3.avi'

# Pixel threshold
pixel_threshold = 125

# Pixel size (should be in microns)
pixel_size = 1.0 

# Time step
dt = 0.1 

# Output directory 
root_output_directory = '%s/../output2/' % os.getcwd()
############ INPUTS PANEL, YOU CAN EDIT THIS PANEL ############

# %%
################# PLEASE DON'T EDIT THIS PANEL #################
# Verify the input parameters, and return the path where the output data will be written  
output_directory = file_utils.veryify_input_options(
    video_sequence=video_sequence, output_directory=root_output_directory, 
    pixel_threshold=pixel_threshold, pixel_size=pixel_size, dt=dt)

# Load the frames from the video 
print('* Loading frames')
frames = video_processing.get_frames_list_from_video(video_path=video_sequence, verbose=True)
print('\t* Frames loaded!')
################# PLEASE DON'T EDIT THIS PANEL #################
# Out:
# NOTE: The output path [C:\Users\valad\Documents\GitHub\hidpy\notebooks/../output2/] exists
# * Loading frames
# 	* Video Details:
#   	* Name: C:\Users\valad\Documents\GitHub\hidpy\notebooks/../data/microscopes/dna/3.avi
#   	* Number Frames -1  	* FPS: 7.000000
# |                                                  | 0/0 [00:00<?, ?it/s]
# 	* Frames loaded!

# %%
################# PLEASE DON'T EDIT THIS PANEL #################
# Compute the optical flow
print('* Computing optical flow') 
u, v = optical_flow.compute_optical_flow_farneback(frames=frames)
print('\t* Optical flow computed!\n') 

# Interpolate the flow field
print('* Computing interpolations')
u, v = optical_flow.interpolate_flow_fields(u_arrays=u, v_arrays=v)
print('\t* Interpolations computed!\n')

# Compute the trajectories 
print('* Creating trajectories')
trajectories = optical_flow.compute_trajectories(
    frame=frames[0], fu_arrays=u, fv_arrays=v, pixel_threshold=pixel_threshold)
print('\t* Trajectories created!\n')

# Plot the trajectories 
print('* Plotting trajectories')
plotting.plot_trajectories_on_frame(
    frame=frames[0], trajectories=trajectories, 
    output_path='%s/trajectories' % output_directory)
print('\t* Trajectories rendered!\n')

################## PLEASE DON'T EDIT THIS PANEL #################
# Out:
# * Computing optical flow
# |                                                  | 0/0 [00:00<?, ?it/s]
# Optical flow time 0.005004
# 	* Optical flow computed!
#
# * Computing interpolations
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\valad\Documents\GitHub\hidpy\notebooks\02-hidpy-stage-1.ipynb Celda 5 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/valad/Documents/GitHub/hidpy/notebooks/02-hidpy-stage-1.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> # Interpolate the flow field
#       <a href='vscode-notebook-cell:/c%3A/Users/valad/Documents/GitHub/hidpy/notebooks/02-hidpy-stage-1.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> print('* Computing interpolations')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/valad/Documents/GitHub/hidpy/notebooks/02-hidpy-stage-1.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> u, v = optical_flow.interpolate_flow_fields(u_arrays=u, v_arrays=v)
#      <a href='vscode-notebook-cell:/c%3A/Users/valad/Documents/GitHub/hidpy/notebooks/02-hidpy-stage-1.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> print('\t* Interpolations computed!\n')
#      <a href='vscode-notebook-cell:/c%3A/Users/valad/Documents/GitHub/hidpy/notebooks/02-hidpy-stage-1.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> # Compute the trajectories
#
# File c:\Users\valad\Documents\GitHub\hidpy\notebooks/..\core\optical_flow.py:31, in interpolate_flow_fields(u_arrays, v_arrays)
#      28 fv_arrays = list()
#      30 # Create the axes of the mesh grid
# ---> 31 x_axis = numpy.arange(u_arrays[0].shape[0])
#      32 y_axis = numpy.arange(u_arrays[0].shape[1])
#      34 # For every time step
#
# IndexError: list index out of range

# %%
# Calculation of the MSD (mean square displacement)

# Construct trajectory map
print('* Converting the trajectories to maps')
xp, yp = msd.convert_trajectories_to_map(trajectories, (len(frames), frames[0].shape[0], frames[0].shape[1]))

# extract nucleoli mask
print('* Extracting the nucleoli map')
mask_nucleoli = msd.extract_nucleoli_map(xp, yp)

# Compute the MSDs
print('* Computing the MSDs')
MSD = msd.calculate_msd_for_every_pixel(xp, yp, mask_nucleoli)

# Baysian fit on MSDs
print('* Fitting the MSDs models using Bayesian inference')

### THIS SHOULD BE SELECTED FROM THE CONFIG FILE 
models_selected = ['D','DA','V','DV','DAV'] 

# THE TIME STEO SHOULD BE SET IN THE CONFIG GILE 
dT = dt
Bayes = inference.apply_bayesian_inference(MSD, dT, models_selected)
# Out:
# * Converting the trajectories to maps
# * Extracting the nucleoli map
# * Computing the MSDs
# * Fitting the MSDs models using Bayesian inference
# Bayesian inference..
# Using # cores:8
#   0%|          | 8/46017 [00:01<1:38:26,  7.79it/s]<frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
#   0%|          | 16/46017 [00:01<54:48, 13.99it/s] <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
#   0%|          | 24/46017 [00:01<40:03, 19.14it/s]<frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
#   6%|▌         | 2800/46017 [01:06<16:05, 44.74it/s]
# Warning: regularization failed
#   8%|▊         | 3568/46017 [01:23<14:39, 48.27it/s]
# Warning: regularization failed
# Warning: regularization failed
#   8%|▊         | 3816/46017 [01:29<16:32, 42.52it/s]
# Warning: regularization failed
# Warning: regularization failed
#   9%|▉         | 4072/46017 [01:35<15:52, 44.02it/s]
# Warning: regularization failed
#   9%|▉         | 4208/46017 [01:38<14:32, 47.90it/s]
# Warning: regularization failed
# Warning: regularization failed
#  10%|█         | 4608/46017 [01:47<16:04, 42.93it/s]
# Warning: regularization failed
#  10%|█         | 4752/46017 [01:50<15:38, 43.99it/s]
# Warning: regularization failed
#  17%|█▋        | 7624/46017 [02:55<13:02, 49.08it/s]
# Warning: regularization failed
#  18%|█▊        | 8432/46017 [03:13<15:02, 41.64it/s]
# Warning: regularization failed
# Warning: regularization failed
#  19%|█▉        | 8648/46017 [03:17<13:51, 44.93it/s]
# Warning: regularization failed
#  19%|█▉        | 8744/46017 [03:20<17:03, 36.42it/s]
# Warning: regularization failed
#  19%|█▉        | 8784/46017 [03:20<12:40, 48.98it/s]
# Warning: regularization failed
#  19%|█▉        | 8936/46017 [03:24<13:29, 45.81it/s]
# Warning: regularization failed
#  20%|██        | 9304/46017 [03:32<13:59, 43.75it/s]
# Warning: regularization failed
#  21%|██        | 9640/46017 [03:40<13:14, 45.79it/s]
# Warning: regularization failed
#  25%|██▍       | 11424/46017 [04:21<13:32, 42.58it/s]
# Warning: regularization failed
#  26%|██▌       | 11808/46017 [04:30<12:59, 43.90it/s]
# Warning: regularization failed
#  32%|███▏      | 14568/46017 [05:33<10:54, 48.09it/s]
# Warning: regularization failed
#  32%|███▏      | 14752/46017 [05:37<11:05, 47.00it/s]
# Warning: regularization failed
# Warning: regularization failed
#  41%|████▏     | 19024/46017 [07:15<10:23, 43.27it/s]
# Warning: regularization failed
#  42%|████▏     | 19224/46017 [07:19<09:30, 47.00it/s]
# Warning: regularization failed
#  42%|████▏     | 19400/46017 [07:23<09:09, 48.44it/s]
# Warning: regularization failed
#  42%|████▏     | 19472/46017 [07:24<10:03, 44.01it/s]
# Warning: regularization failed
#  43%|████▎     | 19616/46017 [07:28<09:25, 46.65it/s]
# Warning: regularization failed
#  43%|████▎     | 19792/46017 [07:32<09:05, 48.09it/s]
# Warning: regularization failed
# Warning: regularization failed
#  43%|████▎     | 19920/46017 [07:34<08:42, 49.92it/s]
# Warning: regularization failed
#  44%|████▎     | 20048/46017 [07:37<10:35, 40.84it/s]
# Warning: regularization failed
#  44%|████▍     | 20360/46017 [07:44<09:14, 46.27it/s]
# Warning: regularization failed
#  44%|████▍     | 20376/46017 [07:45<09:23, 45.49it/s]
# Warning: regularization failed
#  45%|████▍     | 20624/46017 [07:50<09:10, 46.10it/s]
# Warning: regularization failed
#  46%|████▌     | 20976/46017 [07:58<09:42, 43.00it/s]
# Warning: regularization failed
#  53%|█████▎    | 24264/46017 [09:12<07:32, 48.10it/s]
# Warning: regularization failed
#  53%|█████▎    | 24384/46017 [09:14<07:58, 45.19it/s]
# Warning: regularization failed
#  53%|█████▎    | 24504/46017 [09:17<08:37, 41.54it/s]
# Warning: regularization failed
#  53%|█████▎    | 24600/46017 [09:19<07:43, 46.18it/s]
# Warning: regularization failed
# Warning: regularization failed
# Warning: regularization failed
#  54%|█████▍    | 25032/46017 [09:29<08:13, 42.51it/s]
# Warning: regularization failed
#  55%|█████▍    | 25216/46017 [09:33<07:37, 45.46it/s]
# Warning: regularization failed
#  55%|█████▍    | 25248/46017 [09:34<08:01, 43.16it/s]
# Warning: regularization failed
# Warning: regularization failed
#  57%|█████▋    | 26008/46017 [09:51<06:18, 52.88it/s]
# Warning: regularization failed
#  57%|█████▋    | 26120/46017 [09:53<06:30, 50.89it/s]
# Warning: regularization failed
#  57%|█████▋    | 26232/46017 [09:56<06:55, 47.60it/s]
# Warning: regularization failed
#  58%|█████▊    | 26576/46017 [10:03<07:01, 46.09it/s]
# Warning: regularization failed
# Warning: regularization failed
#  58%|█████▊    | 26728/46017 [10:06<06:55, 46.43it/s]
# Warning: regularization failed
#  59%|█████▉    | 27208/46017 [10:17<06:15, 50.06it/s]
# Warning: regularization failed
#  64%|██████▍   | 29648/46017 [11:11<06:22, 42.81it/s]
# Warning: regularization failed
#  64%|██████▍   | 29672/46017 [11:11<06:00, 45.36it/s]
# Warning: regularization failed
#  65%|██████▍   | 29808/46017 [11:14<05:34, 48.49it/s]
# Warning: regularization failed
#  65%|██████▍   | 29880/46017 [11:16<05:45, 46.72it/s]
# Warning: regularization failed
#  65%|██████▍   | 29904/46017 [11:16<05:55, 45.30it/s]
# Warning: regularization failed
#  68%|██████▊   | 31184/46017 [11:44<05:20, 46.32it/s]
# Warning: regularization failed
#  70%|██████▉   | 32008/46017 [12:02<04:50, 48.30it/s]
# Warning: regularization failed
#  70%|███████   | 32408/46017 [12:10<04:52, 46.56it/s]
# Warning: regularization failed
#  71%|███████   | 32608/46017 [12:15<04:47, 46.71it/s]
# Warning: regularization failed
#  72%|███████▏  | 33232/46017 [12:29<04:55, 43.19it/s]
# Warning: regularization failed
#  73%|███████▎  | 33584/46017 [12:37<04:36, 44.93it/s]
# Warning: regularization failed
#  75%|███████▌  | 34664/46017 [13:01<04:23, 43.04it/s]
# Warning: regularization failed
#  76%|███████▌  | 35048/46017 [13:09<03:50, 47.49it/s]
# Warning: regularization failed
#  78%|███████▊  | 35808/46017 [13:27<04:02, 42.17it/s]
# Warning: regularization failed
#  79%|███████▊  | 36200/46017 [13:36<03:57, 41.34it/s]
# Warning: regularization failed
#  80%|████████  | 36816/46017 [13:50<03:04, 49.87it/s]
# Warning: regularization failed
# Warning: regularization failed
#  82%|████████▏ | 37640/46017 [14:08<02:53, 48.28it/s]
# Warning: regularization failed
#  86%|████████▌ | 39520/46017 [14:51<02:30, 43.21it/s]
# Warning: regularization failed
#  86%|████████▌ | 39624/46017 [14:54<02:28, 43.00it/s]
# Warning: regularization failed
# Warning: regularization failed
#  87%|████████▋ | 39824/46017 [14:58<02:16, 45.45it/s]
# Warning: regularization failed
#  89%|████████▉ | 41176/46017 [15:28<01:45, 45.99it/s]
# Warning: regularization failed
#  90%|████████▉ | 41352/46017 [15:32<01:40, 46.25it/s]
# Warning: regularization failed
#  92%|█████████▏| 42160/46017 [15:51<01:18, 48.85it/s]
# Warning: regularization failed
#  92%|█████████▏| 42368/46017 [15:56<01:31, 39.74it/s]
# Warning: regularization failed
#  94%|█████████▎| 43056/46017 [16:12<01:01, 47.77it/s]
# Warning: regularization failed
#  94%|█████████▍| 43176/46017 [16:14<01:01, 46.17it/s]
# Warning: regularization failed
#  97%|█████████▋| 44520/46017 [16:43<00:32, 45.65it/s]
# Warning: regularization failed
#  97%|█████████▋| 44632/46017 [16:45<00:28, 48.00it/s]
# Warning: regularization failed
#  97%|█████████▋| 44792/46017 [16:49<00:27, 44.95it/s]
# Warning: regularization failed
# 100%|██████████| 46017/46017 [17:17<00:00, 44.37it/s]
# 100%|██████████| 46017/46017 [00:54<00:00, 844.01it/s]

# %%
from pylab import *
from matplotlib import colors

matrix1=np.zeros((frames[0].shape[0],frames[0].shape[1]))
matrix1[np.where(mask_nucleoli==1)]=100

bounds = [0.5, 1.5, 2.5, 3.5, 4.5]

fig,ax=plt.subplots(2,3,figsize=[12,10])
ax[0,2].axis('off')

img0=ax[0,0].imshow(frames[0],origin='lower',cmap='gray')
ax[0,0].set_title('Raw image')

cmap = colors.ListedColormap(['w','g','b','purple','r','greenyellow'])
img1=ax[0,1].imshow(Bayes['model'], interpolation='nearest',cmap=cmap,origin='lower')
ax[0,1].contour(matrix1, colors='k', origin='lower')

cbar=fig.colorbar(img1,ax=ax[0,1],spacing='proportional',orientation='horizontal',boundaries=[-0.5] + bounds + [5.5])
labels = np.arange(0, 6, 1)
loc = labels
cbar.set_ticks(loc)
cbar.set_ticklabels([' ','D','DA','V','DV','DAV'])
ax[0,1].set_title('Model Selection')

matD=[]
matD=Bayes['D']
matD[np.where(Bayes['model']==0)]=np.nan
matD[np.where(Bayes['D']<1e-10)]=np.nan

# #figure(2)
img2=ax[1,0].imshow(matD, interpolation='nearest',cmap='viridis',origin='lower')
ax[1,0].contour(matrix1, colors='k', origin='lower')
fig.colorbar(img2,ax=ax[1,0],spacing='proportional',orientation='horizontal')
ax[1,0].set_title(r'Diffusion constant [$\mu$m$^2$/s]')

matA=[]
matA=Bayes['A']
matA[np.where(Bayes['model']==0)]=np.nan
matA[np.where(Bayes['A']<1e-10)]=np.nan

# #figure(3)
img3=ax[1,1].imshow(matA, interpolation='nearest',cmap='viridis',origin='lower')
ax[1,1].contour(matrix1, colors='k', origin='lower')
fig.colorbar(img3,ax=ax[1,1],spacing='proportional',orientation='horizontal')
ax[1,1].set_title('Anomalous exponent')

matV=[]
matV=Bayes['V']
matV[np.where(Bayes['model']==0)]=np.nan
matV[np.where(Bayes['V']==0)]=np.nan

# #figure(4)
img4=ax[1,2].imshow(matV, interpolation='nearest',cmap='viridis',origin='lower')
ax[1,2].contour(matrix1, colors='k', origin='lower')
fig.colorbar(img4,ax=ax[1,2],spacing='proportional',orientation='horizontal')
ax[1,2].set_title(r'Drift velocity [$\mu$m/s]')
# Out:
# Text(0.5, 1.0, 'Drift velocity [$\\mu$m/s]')

# %%
# Save pickle file per cell

import pickle

output_b = output_directory + "/" + "ex"
os.mkdir(output_b)

with open('%s/Results_Bayes_04102022_Cell01.pickle' % output_b, 'wb') as f:
    pickle.dump(Bayes, f)
